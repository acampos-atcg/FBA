# %%
import escher
import escher.urls
import cobra
import cobra.test
import json
import os
from IPython.display import HTML
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *
from cobra.flux_analysis.phenotype_phase_plane import calculate_phenotype_phase_plane
# %matplotlib inline

# %% [markdown]
# # Optimizacion default

# %%
model = cobra.io.read_sbml_model('Ec_core_flux1.xml')
solution=model.optimize()
b = escher.Builder(map_name='iJO1366.Central metabolism',
                   reaction_data=solution.x_dict,
                   # color and size according to the absolute value
                   reaction_styles=['color', 'size', 'abs', 'text'],
                   # change the default colors
                   reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                                   {'type': 'mean', 'color': '#0000dd', 'size': 20},
                                   {'type': 'max', 'color': '#ff0000', 'size': 40}],
                   # only show the primary metabolites
                   hide_secondary_metabolites=True)
b.display_in_notebook()
# Out:
#   <!-- These are not generally used within the notebook. -->
#   <script src=""></script>
#   <script src=""></script>
#
#   <link rel="stylesheet" href=""/>
#   <link rel="stylesheet" href="//escher.github.io/builder-1.1.2.css"/>
#
#
#
#   <div style="height: 500px; width: 100%;" id="cditbyudfd"></div>
#
#   <script>
#    var map_data_cditbyudfd = [{"map_name":"iJO1366.Central metabolism","map_id":"23lkrjf93","map_description":"Central metabolism (iJO1366)\nLast Modified Mon Jan 26 2015 18:16:37 GMT-0800 (PST)","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"2075839":{"name":"malate dehydrogenase","bigg_id":"MDH","reversibility":true,"label_x":3019.1480390625,"label_y":3883.49973125,"gene_reaction_rule":"b3236","genes":[{"bigg_id":"b3236","name":"b3236"}],"metabolites":[{"coefficient":-1,"bigg_id":"mal__L_c"},{"coefficient":-1,"bigg_id":"nad_c"},{"coefficient":1,"bigg_id":"h_c"},{"coefficient":1,"bigg_id":"oaa_c"},{"coefficient":1,"bigg_id":"nadh_c"}],"segments":{"675":{"from_node_id":"2076049","to_node_id":"2076047","b1":null,"b2":null},"676":{"from_node_id":"2076047","to_node_id":"2076048","b1":null,"b2":null},"677":{"from_node_id":"2075291","to_node_id":"2076049","b1":{"x":3014.9175703125,"y":3678.094009828363},"b2":{"x":2996.16659375,"y":3828.010534354759}},"678":{"from_node_id":"2075292","to_node_id":"2076049","b1":{"x":3009.1480390625,"y":3815.769549805468},"b2":{"x":2996.16659375,"y":3840.3213018166402}},"679":{"from_node_id":"2076048","to_node_id":"2075293","b1":{"x":2997.086199423056,"y":3948.7830375230687},"b2":{"x":3008.0275189101862,"y":4033.7927183060624}},"680":{"from_node_id":"2076048","to_node_id":"2075294","b1":{"x":2997.010450627502,"y":3945.298592927578},"b2":{"x":3004.890257300006,"y":3991.887863925259}},"681":{"from_node_id":"2076048","to_node_id":"2075295","b1":{"x":2997.385174856572,"y":3962.535907464812},"b2":{"x":2994.6002755635736,"y":4013.2860087368736}}}},"2075840":{"name":"nitrite Reductase (Ubiquinole-8, periplasm)","bigg_id":"NTRIR3pp","reversibility":false,"label_x":7909.30788847041,"label_y":542.0664407649147,"gene_reaction_rule":"(b4070 and b4071 and b4072 and b4073)","genes":[{"bigg_id":"b4070","name":"b4070"},{"bigg_id":"b4071","name":"b4071"},{"bigg_id":"b4072","name":"b4072"},{"bigg_id":"b4073","name":"b4073"}],"metabolites":[{"coefficient":-2,"bigg_id":"h_p"},{"coefficient":-1,"bigg_id":"no2_p"},{"coefficient":1,"bigg_id":"nh4_p"},{"coefficient":3,"bigg_id":"q8_c"},{"coefficient":-3,"bigg_id":"q8h2_c"},{"coefficient":2,"bigg_id":"h2o_p"}],"segments":{"682":{"from_node_id":"2076052","to_node_id":"2076051","b1":null,"b2":null},"683":{"from_node_id":"2076051","to_node_id":"2076050","b1":null,"b2":null},"684":{"from_node_id":"2075296","to_node_id":"2076052","b1":{"x":7663.71393359375,"y":570.5693103826193},"b2":{"x":7759.170323406532,"y":572.8209134831445}},"685":{"from_node_id":"2075297","to_node_id":"2076052","b1":{"x":7831.4065919529285,"y":566.4849670569738},"b2":{"x":7900.712901044808,"y":576.142835824231}},"686":{"from_node_id":"2075298","to_node_id":"2076052","b1":{"x":7843.409319920852,"y":556.4883424688724},"b2":{"x":7910.108934278935,"y":576.3633552837393}},"687":{"from_node_id":"2076050","to_node_id":"2075299","b1":{"x":8037.493493996242,"y":579.3529971420026},"b2":{"x":8090.560108211032,"y":569.5644518094982}},"688":{"from_node_id":"2076050","to_node_id":"2075300","b1":{"x":8800.274575301122,"y":595.0407642693121},"b2":{"x":9245.56647265625,"y":2548.8462553831623}},"689":{"from_node_id":"2076050","to_node_id":"2075301","b1":{"x":8044.550119579862,"y":579.5186120585186},"b2":{"x":8109.789224739774,"y":572.2628638359038}}}},"2075841":{"name":"NADPH Quinone Reductase (2-Demethylmenaquinone-8)","bigg_id":"NADPHQR4","reversibility":false,"label_x":7366.89071484375,"label_y":5631.57130859375,"gene_reaction_rule":"b3028","genes":[{"bigg_id":"b3028","name":"b3028"}],"metabolites":[{"coefficient":-1,"bigg_id":"2dmmq8_c"},{"coefficient":1,"bigg_id":"nadp_c"},{"coefficient":-1,"bigg_id":"h_c"},{"coefficient":1,"bigg_id":"2dmmql8_c"},{"coefficient":-1,"bigg_id":"nadph_c"}],"segments":{"690":{"from_node_id":"2076053","to_node_id":"2076054","b1":null,"b2":null},"691":{"from_node_id":"2076054","to_node_id":"2076055","b1":null,"b2":null},"692":{ ...

# %%
solution=model.optimize()
b = escher.Builder(map_name='iJO1366.Central metabolism',
                   reaction_data=solution.x_dict,
                   # color and size according to the absolute value
                   reaction_styles=['color', 'size', 'abs', 'text'],
                   # change the default colors
                   reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                                   {'type': 'mean', 'color': '#0000dd', 'size': 20},
                                   {'type': 'max', 'color': '#ff0000', 'size': 40}],
                   # only show the primary metabolites
                   hide_secondary_metabolites=True)
b.display_in_notebook()
# Out:
#   <!-- These are not generally used within the notebook. -->
#   <script src=""></script>
#   <script src=""></script>
#
#   <link rel="stylesheet" href=""/>
#   <link rel="stylesheet" href="//escher.github.io/builder-1.1.2.css"/>
#
#
#
#   <div style="height: 500px; width: 100%;" id="rktsnavdrx"></div>
#
#   <script>
#    var map_data_rktsnavdrx = [{"map_name":"iJO1366.Central metabolism","map_id":"23lkrjf93","map_description":"Central metabolism (iJO1366)\nLast Modified Mon Jan 26 2015 18:16:37 GMT-0800 (PST)","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"2075839":{"name":"malate dehydrogenase","bigg_id":"MDH","reversibility":true,"label_x":3019.1480390625,"label_y":3883.49973125,"gene_reaction_rule":"b3236","genes":[{"bigg_id":"b3236","name":"b3236"}],"metabolites":[{"coefficient":-1,"bigg_id":"mal__L_c"},{"coefficient":-1,"bigg_id":"nad_c"},{"coefficient":1,"bigg_id":"h_c"},{"coefficient":1,"bigg_id":"oaa_c"},{"coefficient":1,"bigg_id":"nadh_c"}],"segments":{"675":{"from_node_id":"2076049","to_node_id":"2076047","b1":null,"b2":null},"676":{"from_node_id":"2076047","to_node_id":"2076048","b1":null,"b2":null},"677":{"from_node_id":"2075291","to_node_id":"2076049","b1":{"x":3014.9175703125,"y":3678.094009828363},"b2":{"x":2996.16659375,"y":3828.010534354759}},"678":{"from_node_id":"2075292","to_node_id":"2076049","b1":{"x":3009.1480390625,"y":3815.769549805468},"b2":{"x":2996.16659375,"y":3840.3213018166402}},"679":{"from_node_id":"2076048","to_node_id":"2075293","b1":{"x":2997.086199423056,"y":3948.7830375230687},"b2":{"x":3008.0275189101862,"y":4033.7927183060624}},"680":{"from_node_id":"2076048","to_node_id":"2075294","b1":{"x":2997.010450627502,"y":3945.298592927578},"b2":{"x":3004.890257300006,"y":3991.887863925259}},"681":{"from_node_id":"2076048","to_node_id":"2075295","b1":{"x":2997.385174856572,"y":3962.535907464812},"b2":{"x":2994.6002755635736,"y":4013.2860087368736}}}},"2075840":{"name":"nitrite Reductase (Ubiquinole-8, periplasm)","bigg_id":"NTRIR3pp","reversibility":false,"label_x":7909.30788847041,"label_y":542.0664407649147,"gene_reaction_rule":"(b4070 and b4071 and b4072 and b4073)","genes":[{"bigg_id":"b4070","name":"b4070"},{"bigg_id":"b4071","name":"b4071"},{"bigg_id":"b4072","name":"b4072"},{"bigg_id":"b4073","name":"b4073"}],"metabolites":[{"coefficient":-2,"bigg_id":"h_p"},{"coefficient":-1,"bigg_id":"no2_p"},{"coefficient":1,"bigg_id":"nh4_p"},{"coefficient":3,"bigg_id":"q8_c"},{"coefficient":-3,"bigg_id":"q8h2_c"},{"coefficient":2,"bigg_id":"h2o_p"}],"segments":{"682":{"from_node_id":"2076052","to_node_id":"2076051","b1":null,"b2":null},"683":{"from_node_id":"2076051","to_node_id":"2076050","b1":null,"b2":null},"684":{"from_node_id":"2075296","to_node_id":"2076052","b1":{"x":7663.71393359375,"y":570.5693103826193},"b2":{"x":7759.170323406532,"y":572.8209134831445}},"685":{"from_node_id":"2075297","to_node_id":"2076052","b1":{"x":7831.4065919529285,"y":566.4849670569738},"b2":{"x":7900.712901044808,"y":576.142835824231}},"686":{"from_node_id":"2075298","to_node_id":"2076052","b1":{"x":7843.409319920852,"y":556.4883424688724},"b2":{"x":7910.108934278935,"y":576.3633552837393}},"687":{"from_node_id":"2076050","to_node_id":"2075299","b1":{"x":8037.493493996242,"y":579.3529971420026},"b2":{"x":8090.560108211032,"y":569.5644518094982}},"688":{"from_node_id":"2076050","to_node_id":"2075300","b1":{"x":8800.274575301122,"y":595.0407642693121},"b2":{"x":9245.56647265625,"y":2548.8462553831623}},"689":{"from_node_id":"2076050","to_node_id":"2075301","b1":{"x":8044.550119579862,"y":579.5186120585186},"b2":{"x":8109.789224739774,"y":572.2628638359038}}}},"2075841":{"name":"NADPH Quinone Reductase (2-Demethylmenaquinone-8)","bigg_id":"NADPHQR4","reversibility":false,"label_x":7366.89071484375,"label_y":5631.57130859375,"gene_reaction_rule":"b3028","genes":[{"bigg_id":"b3028","name":"b3028"}],"metabolites":[{"coefficient":-1,"bigg_id":"2dmmq8_c"},{"coefficient":1,"bigg_id":"nadp_c"},{"coefficient":-1,"bigg_id":"h_c"},{"coefficient":1,"bigg_id":"2dmmql8_c"},{"coefficient":-1,"bigg_id":"nadph_c"}],"segments":{"690":{"from_node_id":"2076053","to_node_id":"2076054","b1":null,"b2":null},"691":{"from_node_id":"2076054","to_node_id":"2076055","b1":null,"b2":null},"692":{ ...

# %%
model = cobra.io.read_sbml_model('Ec_core_flux1.xml')
model.reactions.GAPD.upper_bound=0.1
model.optimize()
# Out:
# <Solution 0.01 at 0x7f2ffdae4890>

# %%
x=[]
y=[]
z=[]
model = cobra.io.read_sbml_model('Ec_core_flux1.xml')
for i in np.arange(0,20,0.1):
    for p in np.arange(i,20,0.1):
        model.reactions.GAPD.lower_bound=i
        model.reactions.GAPD.upper_bound=p
        model.optimize()
        x.append(i)
        y.append(p)
        z.append(model.solution.f)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot3D(x,y,z)
ax.set_xlabel('GAPD lower bound')
ax.set_ylabel('GAPD upper bound')
ax.set_zlabel('Growth')
plt.show()

# %%
x=[]
y=[]
model = cobra.io.read_sbml_model('Ec_core_flux1.xml')
for i in np.arange(0,20,0.1):
        model.reactions.GAPD.lower_bound=i
        model.optimize()
        x.append(i)
        y.append(model.solution.f)
        
print model.reactions.GAPD.upper_bound
plt.plot(x,y,'co')
plt.xlabel('GADP lower limit')
plt.ylabel('Growth maximum')
plt.show()
# Out:
# 999999.0

# %%
x=[]
y=[]
model = cobra.io.read_sbml_model('Ec_core_flux1.xml')
for i in np.arange(0.1,20,0.1):
        model.reactions.GAPD.upper_bound= i
        model.optimize()
        x.append(i)
        y.append(model.solution.f)
plt.xlabel('GADP upper limit')
plt.ylabel('Growth maximum')
plt.plot(x,y,'go')
plt.show()
